# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
#Word Segmentation
stop_words = set(stopwords.words('english'))
content = "So even though we face the difficulties of today and tomorrow, I still have a dream.\n', 'I have a dream that one day this nation will rise up and live out the true meaning of its creed.\n', 'We hold these truths to be self-evident, that all men are created equal.\n', 'I have a dream that one day even the state of Mississippi, a state sweltering with the heat of injustice, sweltering with the heat of oppression, will be transformed into an oasis of freedom and justice.\n', 'I have a dream that one day, down in Alabama, with its vicious racists, with its governor having his lips dripping with the words of interposition and nullification, one day right there in Alabama little black boys and black girls will be able to join hands with little white boys and white girls as sisters and brothers.\n', 'This is our hope, and this is the faith that I go back to the South with.\n', 'With this faith, we will be able to hew out of the mountain of despair a stone of hope. With this faith, we will be able to transform the jangling discords of our nation into a beautiful symphony of brotherhood.\n"
word_tokens = word_tokenize(content)
print(word_tokens)
# Out:
# ['So', 'even', 'though', 'we', 'face', 'the', 'difficulties', 'of', 'today', 'and', 'tomorrow', ',', 'I', 'still', 'have', 'a', 'dream', '.', "'", ',', "'", 'I', 'have', 'a', 'dream', 'that', 'one', 'day', 'this', 'nation', 'will', 'rise', 'up', 'and', 'live', 'out', 'the', 'true', 'meaning', 'of', 'its', 'creed', '.', "'", ',', "'We", 'hold', 'these', 'truths', 'to', 'be', 'self-evident', ',', 'that', 'all', 'men', 'are', 'created', 'equal', '.', "'", ',', "'", 'I', 'have', 'a', 'dream', 'that', 'one', 'day', 'even', 'the', 'state', 'of', 'Mississippi', ',', 'a', 'state', 'sweltering', 'with', 'the', 'heat', 'of', 'injustice', ',', 'sweltering', 'with', 'the', 'heat', 'of', 'oppression', ',', 'will', 'be', 'transformed', 'into', 'an', 'oasis', 'of', 'freedom', 'and', 'justice', '.', "'", ',', "'", 'I', 'have', 'a', 'dream', 'that', 'one', 'day', ',', 'down', 'in', 'Alabama', ',', 'with', 'its', 'vicious', 'racists', ',', 'with', 'its', 'governor', 'having', 'his', 'lips', 'dripping', 'with', 'the', 'words', 'of', 'interposition', 'and', 'nullification', ',', 'one', 'day', 'right', 'there', 'in', 'Alabama', 'little', 'black', 'boys', 'and', 'black', 'girls', 'will', 'be', 'able', 'to', 'join', 'hands', 'with', 'little', 'white', 'boys', 'and', 'white', 'girls', 'as', 'sisters', 'and', 'brothers', '.', "'", ',', "'This", 'is', 'our', 'hope', ',', 'and', 'this', 'is', 'the', 'faith', 'that', 'I', 'go', 'back', 'to', 'the', 'South', 'with', '.', "'", ',', "'With", 'this', 'faith', ',', 'we', 'will', 'be', 'able', 'to', 'hew', 'out', 'of', 'the', 'mountain', 'of', 'despair', 'a', 'stone', 'of', 'hope', '.', 'With', 'this', 'faith', ',', 'we', 'will', 'be', 'able', 'to', 'transform', 'the', 'jangling', 'discords', 'of', 'our', 'nation', 'into', 'a', 'beautiful', 'symphony', 'of', 'brotherhood', '.']

# %%
#Sentence Segmentation
sent_tokens = sent_tokenize(content)
print(sent_tokens)
# Out:
# ['So even though we face the difficulties of today and tomorrow, I still have a dream.', "', 'I have a dream that one day this nation will rise up and live out the true meaning of its creed.", "', 'We hold these truths to be self-evident, that all men are created equal.", "', 'I have a dream that one day even the state of Mississippi, a state sweltering with the heat of injustice, sweltering with the heat of oppression, will be transformed into an oasis of freedom and justice.", "', 'I have a dream that one day, down in Alabama, with its vicious racists, with its governor having his lips dripping with the words of interposition and nullification, one day right there in Alabama little black boys and black girls will be able to join hands with little white boys and white girls as sisters and brothers.", "', 'This is our hope, and this is the faith that I go back to the South with.", "', 'With this faith, we will be able to hew out of the mountain of despair a stone of hope.", 'With this faith, we will be able to transform the jangling discords of our nation into a beautiful symphony of brotherhood.']

# %%
#Lowercase
content.lower()
# Out:
# "so even though we face the difficulties of today and tomorrow, i still have a dream.\n', 'i have a dream that one day this nation will rise up and live out the true meaning of its creed.\n', 'we hold these truths to be self-evident, that all men are created equal.\n', 'i have a dream that one day even the state of mississippi, a state sweltering with the heat of injustice, sweltering with the heat of oppression, will be transformed into an oasis of freedom and justice.\n', 'i have a dream that one day, down in alabama, with its vicious racists, with its governor having his lips dripping with the words of interposition and nullification, one day right there in alabama little black boys and black girls will be able to join hands with little white boys and white girls as sisters and brothers.\n', 'this is our hope, and this is the faith that i go back to the south with.\n', 'with this faith, we will be able to hew out of the mountain of despair a stone of hope. with this faith, we will be able to transform the jangling discords of our nation into a beautiful symphony of brotherhood.\n"

# %%
#Stop Words Removal

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
filtered_sentence = []
  
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
  
print(word_tokens)
print(filtered_sentence)
# Out:
# ['So', 'even', 'though', 'we', 'face', 'the', 'difficulties', 'of', 'today', 'and', 'tomorrow', ',', 'I', 'still', 'have', 'a', 'dream', '.', "'", ',', "'", 'I', 'have', 'a', 'dream', 'that', 'one', 'day', 'this', 'nation', 'will', 'rise', 'up', 'and', 'live', 'out', 'the', 'true', 'meaning', 'of', 'its', 'creed', '.', "'", ',', "'We", 'hold', 'these', 'truths', 'to', 'be', 'self-evident', ',', 'that', 'all', 'men', 'are', 'created', 'equal', '.', "'", ',', "'", 'I', 'have', 'a', 'dream', 'that', 'one', 'day', 'even', 'the', 'state', 'of', 'Mississippi', ',', 'a', 'state', 'sweltering', 'with', 'the', 'heat', 'of', 'injustice', ',', 'sweltering', 'with', 'the', 'heat', 'of', 'oppression', ',', 'will', 'be', 'transformed', 'into', 'an', 'oasis', 'of', 'freedom', 'and', 'justice', '.', "'", ',', "'", 'I', 'have', 'a', 'dream', 'that', 'one', 'day', ',', 'down', 'in', 'Alabama', ',', 'with', 'its', 'vicious', 'racists', ',', 'with', 'its', 'governor', 'having', 'his', 'lips', 'dripping', 'with', 'the', 'words', 'of', 'interposition', 'and', 'nullification', ',', 'one', 'day', 'right', 'there', 'in', 'Alabama', 'little', 'black', 'boys', 'and', 'black', 'girls', 'will', 'be', 'able', 'to', 'join', 'hands', 'with', 'little', 'white', 'boys', 'and', 'white', 'girls', 'as', 'sisters', 'and', 'brothers', '.', "'", ',', "'This", 'is', 'our', 'hope', ',', 'and', 'this', 'is', 'the', 'faith', 'that', 'I', 'go', 'back', 'to', 'the', 'South', 'with', '.', "'", ',', "'With", 'this', 'faith', ',', 'we', 'will', 'be', 'able', 'to', 'hew', 'out', 'of', 'the', 'mountain', 'of', 'despair', 'a', 'stone', 'of', 'hope', '.', 'With', 'this', 'faith', ',', 'we', 'will', 'be', 'able', 'to', 'transform', 'the', 'jangling', 'discords', 'of', 'our', 'nation', 'into', 'a', 'beautiful', 'symphony', 'of', 'brotherhood', '.']
# ['So', 'even', 'though', 'face', 'difficulties', 'today', 'tomorrow', ',', 'I', 'still', 'dream', '.', "'", ',', "'", 'I', 'dream', 'one', 'day', 'nation', 'rise', 'live', 'true', 'meaning', 'creed', '.', "'", ',', "'We", 'hold', 'truths', 'self-evident', ',', 'men', 'created', 'equal', '.', "'", ',', "'", 'I', 'dream', 'one', 'day', 'even', 'state', 'Mississippi', ',', 'state', 'sweltering', 'heat', 'injustice', ',', 'sweltering', 'heat', 'oppression', ',', 'transformed', 'oasis', 'freedom', 'justice', '.', "'", ',', "'", 'I', 'dream', 'one', 'day', ',', 'Alabama', ',', 'vicious', 'racists', ',', 'governor', 'lips', 'dripping', 'words', 'interposition', 'nullification', ',', 'one', 'day', 'right', 'Alabama', 'little', 'black', 'boys', 'black', 'girls', 'able', 'join', 'hands', 'little', 'white', 'boys', 'white', 'girls', 'sisters', 'brothers', '.', "'", ',', "'This", 'hope', ',', 'faith', 'I', 'go', 'back', 'South', '.', "'", ',', "'With", 'faith', ',', 'able', 'hew', 'mountain', 'despair', 'stone', 'hope', '.', 'With', 'faith', ',', 'able', 'transform', 'jangling', 'discords', 'nation', 'beautiful', 'symphony', 'brotherhood', '.']

# %%
#Stemming
ps = PorterStemmer()
 
for w in word_tokens:
    print(w, " : ", ps.stem(w))
# Out:
# So  :  so
# even  :  even
# though  :  though
# we  :  we
# face  :  face
# the  :  the
# difficulties  :  difficulti
# of  :  of
# today  :  today
# and  :  and
# tomorrow  :  tomorrow
# ,  :  ,
# I  :  i
# still  :  still
# have  :  have
# a  :  a
# dream  :  dream
# .  :  .
# '  :  '
# ,  :  ,
# '  :  '
# I  :  i
# have  :  have
# a  :  a
# dream  :  dream
# that  :  that
# one  :  one
# day  :  day
# this  :  thi
# nation  :  nation
# will  :  will
# rise  :  rise
# up  :  up
# and  :  and
# live  :  live
# out  :  out
# the  :  the
# true  :  true
# meaning  :  mean
# of  :  of
# its  :  it
# creed  :  creed
# .  :  .
# '  :  '
# ,  :  ,
# 'We  :  'we
# hold  :  hold
# these  :  these
# truths  :  truth
# to  :  to
# be  :  be
# self-evident  :  self-evid
# ,  :  ,
# that  :  that
# all  :  all
# men  :  men
# are  :  are
# created  :  creat
# equal  :  equal
# .  :  .
# '  :  '
# ,  :  ,
# '  :  '
# I  :  i
# have  :  have
# a  :  a
# dream  :  dream
# that  :  that
# one  :  one
# day  :  day
# even  :  even
# the  :  the
# state  :  state
# of  :  of
# Mississippi  :  mississippi
# ,  :  ,
# a  :  a
# state  :  state
# sweltering  :  swelter
# with  :  with
# the  :  the
# heat  :  heat
# of  :  of
# injustice  :  injustic
# ,  :  ,
# sweltering  :  swelter
# with  :  with
# the  :  the
# heat  :  heat
# of  :  of
# oppression  :  oppress
# ,  :  ,
# will  :  will
# be  :  be
# transformed  :  transform
# into  :  into
# an  :  an
# oasis  :  oasi
# of  :  of
# freedom  :  freedom
# and  :  and
# justice  :  justic
# .  :  .
# '  :  '
# ,  :  ,
# '  :  '
# I  :  i
# have  :  have
# a  :  a
# dream  :  dream
# that  :  that
# one  :  one
# day  :  day
# ,  :  ,
# down  :  down
# in  :  in
# Alabama  :  alabama
# ,  :  ,
# with  :  with
# its  :  it
# vicious  :  viciou
# racists  :  racist
# ,  :  ,
# with  :  with
# its  :  it
# governor  :  governor
# having  :  have
# his  :  hi
# lips  :  lip
# dripping  :  drip
# with  :  with
# the  :  the
# words  :  word
# of  :  of
# interposition  :  interposit
# and  :  and
# nullification  :  nullif
# ,  :  ,
# one  :  one
# day  :  day
# right  :  right
# there  :  there
# in  :  in
# Alabama  :  alabama
# little  :  littl
# black  :  black
# boys  :  boy
# and  :  and
# black  :  black
# girls  :  girl
# will  :  will
# be  :  be
# able  :  abl
# to  :  to
# join  :  join
# hands  :  hand
# with  :  with
# little  :  littl
# white  :  white
# boys  :  boy
# and  :  and
# white  :  white
# girls  :  girl
# as  :  as
# sisters  :  sister
# and  :  and
# brothers  :  brother
# .  :  .
# '  :  '
# ,  :  ,
# 'This  :  'thi
# is  :  is
# our  :  our
# hope  :  hope
# ,  :  ,
# and  :  and
# this  :  thi
# is  :  is
# the  :  the
# faith  :  faith
# that  :  that
# I  :  i
# go  :  go
# back  :  back
# to  :  to
# the  :  the
# South  :  south
# with  :  with
# .  :  .
# '  :  '
# ,  :  ,
# 'With  :  'with
# this  :  thi
# faith  :  faith
# ,  :  ,
# we  :  we
# will  :  will
# be  :  be
# able  :  abl
# to  :  to
# hew  :  hew
# out  :  out
# of  :  of
# the  :  the
# mountain  :  mountain
# of  :  of
# despair  :  despair
# a  :  a
# stone  :  stone
# of  :  of
# hope  :  hope
# .  :  .
# With  :  with
# this  :  thi
# faith  :  faith
# ,  :  ,
# we  :  we
# will  :  will
# be  :  be
# able  :  abl
# to  :  to
# transform  :  transform
# the  :  the
# jangling  :  jangl
# discords  :  discord
# of  :  of
# our  :  our
# nation  :  nation
# into  :  into
# a  :  a
# beautiful  :  beauti
# symphony  :  symphoni
# of  :  of
# brotherhood  :  brotherhood
# .  :  .

# %%
#Lemmatization
lemmatizer = WordNetLemmatizer()
  
for w in word_tokens:
    print(w + " :", lemmatizer.lemmatize(w))
# Out:
# So : So
# even : even
# though : though
# we : we
# face : face
# the : the
# difficulties : difficulty
# of : of
# today : today
# and : and
# tomorrow : tomorrow
# , : ,
# I : I
# still : still
# have : have
# a : a
# dream : dream
# . : .
# ' : '
# , : ,
# ' : '
# I : I
# have : have
# a : a
# dream : dream
# that : that
# one : one
# day : day
# this : this
# nation : nation
# will : will
# rise : rise
# up : up
# and : and
# live : live
# out : out
# the : the
# true : true
# meaning : meaning
# of : of
# its : it
# creed : creed
# . : .
# ' : '
# , : ,
# 'We : 'We
# hold : hold
# these : these
# truths : truth
# to : to
# be : be
# self-evident : self-evident
# , : ,
# that : that
# all : all
# men : men
# are : are
# created : created
# equal : equal
# . : .
# ' : '
# , : ,
# ' : '
# I : I
# have : have
# a : a
# dream : dream
# that : that
# one : one
# day : day
# even : even
# the : the
# state : state
# of : of
# Mississippi : Mississippi
# , : ,
# a : a
# state : state
# sweltering : sweltering
# with : with
# the : the
# heat : heat
# of : of
# injustice : injustice
# , : ,
# sweltering : sweltering
# with : with
# the : the
# heat : heat
# of : of
# oppression : oppression
# , : ,
# will : will
# be : be
# transformed : transformed
# into : into
# an : an
# oasis : oasis
# of : of
# freedom : freedom
# and : and
# justice : justice
# . : .
# ' : '
# , : ,
# ' : '
# I : I
# have : have
# a : a
# dream : dream
# that : that
# one : one
# day : day
# , : ,
# down : down
# in : in
# Alabama : Alabama
# , : ,
# with : with
# its : it
# vicious : vicious
# racists : racist
# , : ,
# with : with
# its : it
# governor : governor
# having : having
# his : his
# lips : lip
# dripping : dripping
# with : with
# the : the
# words : word
# of : of
# interposition : interposition
# and : and
# nullification : nullification
# , : ,
# one : one
# day : day
# right : right
# there : there
# in : in
# Alabama : Alabama
# little : little
# black : black
# boys : boy
# and : and
# black : black
# girls : girl
# will : will
# be : be
# able : able
# to : to
# join : join
# hands : hand
# with : with
# little : little
# white : white
# boys : boy
# and : and
# white : white
# girls : girl
# as : a
# sisters : sister
# and : and
# brothers : brother
# . : .
# ' : '
# , : ,
# 'This : 'This
# is : is
# our : our
# hope : hope
# , : ,
# and : and
# this : this
# is : is
# the : the
# faith : faith
# that : that
# I : I
# go : go
# back : back
# to : to
# the : the
# South : South
# with : with
# . : .
# ' : '
# , : ,
# 'With : 'With
# this : this
# faith : faith
# , : ,
# we : we
# will : will
# be : be
# able : able
# to : to
# hew : hew
# out : out
# of : of
# the : the
# mountain : mountain
# of : of
# despair : despair
# a : a
# stone : stone
# of : of
# hope : hope
# . : .
# With : With
# this : this
# faith : faith
# , : ,
# we : we
# will : will
# be : be
# able : able
# to : to
# transform : transform
# the : the
# jangling : jangling
# discords : discord
# of : of
# our : our
# nation : nation
# into : into
# a : a
# beautiful : beautiful
# symphony : symphony
# of : of
# brotherhood : brotherhood
# . : .

# %%
#Part of Speech Tagger
tagged = nltk.pos_tag(filtered_sentence)
print(tagged)
# Out:
# [('So', 'RB'), ('even', 'RB'), ('though', 'IN'), ('face', 'NN'), ('difficulties', 'NNS'), ('today', 'NN'), ('tomorrow', 'NN'), (',', ','), ('I', 'PRP'), ('still', 'RB'), ('dream', 'VBP'), ('.', '.'), ("'", "''"), (',', ','), ("'", "''"), ('I', 'PRP'), ('dream', 'VBP'), ('one', 'CD'), ('day', 'NN'), ('nation', 'NN'), ('rise', 'VB'), ('live', 'JJ'), ('true', 'JJ'), ('meaning', 'NN'), ('creed', 'NN'), ('.', '.'), ("'", "''"), (',', ','), ("'We", "''"), ('hold', 'JJ'), ('truths', 'JJ'), ('self-evident', 'JJ'), (',', ','), ('men', 'NNS'), ('created', 'VBD'), ('equal', 'JJ'), ('.', '.'), ("'", "''"), (',', ','), ("'", "''"), ('I', 'PRP'), ('dream', 'VBP'), ('one', 'CD'), ('day', 'NN'), ('even', 'RB'), ('state', 'NN'), ('Mississippi', 'NNP'), (',', ','), ('state', 'NN'), ('sweltering', 'NN'), ('heat', 'NN'), ('injustice', 'NN'), (',', ','), ('sweltering', 'VBG'), ('heat', 'NN'), ('oppression', 'NN'), (',', ','), ('transformed', 'VBD'), ('oasis', 'NN'), ('freedom', 'NN'), ('justice', 'NN'), ('.', '.'), ("'", "''"), (',', ','), ("'", "''"), ('I', 'PRP'), ('dream', 'VBP'), ('one', 'CD'), ('day', 'NN'), (',', ','), ('Alabama', 'NNP'), (',', ','), ('vicious', 'JJ'), ('racists', 'NNS'), (',', ','), ('governor', 'NN'), ('lips', 'NNS'), ('dripping', 'VBG'), ('words', 'NNS'), ('interposition', 'NN'), ('nullification', 'NN'), (',', ','), ('one', 'CD'), ('day', 'NN'), ('right', 'JJ'), ('Alabama', 'NNP'), ('little', 'JJ'), ('black', 'JJ'), ('boys', 'NNS'), ('black', 'JJ'), ('girls', 'NNS'), ('able', 'JJ'), ('join', 'NN'), ('hands', 'VBZ'), ('little', 'JJ'), ('white', 'JJ'), ('boys', 'NNS'), ('white', 'JJ'), ('girls', 'NNS'), ('sisters', 'NNS'), ('brothers', 'NNS'), ('.', '.'), ("'", "''"), (',', ','), ("'This", "''"), ('hope', 'NN'), (',', ','), ('faith', 'NN'), ('I', 'PRP'), ('go', 'VBP'), ('back', 'RB'), ('South', 'NNP'), ('.', '.'), ("'", "''"), (',', ','), ("'With", "''"), ('faith', 'NN'), (',', ','), ('able', 'JJ'), ('hew', 'NN'), ('mountain', 'NN'), ('despair', 'NN'), ('stone', 'NN'), ('hope', 'NN'), ('.', '.'), ('With', 'IN'), ('faith', 'NN'), (',', ','), ('able', 'JJ'), ('transform', 'NN'), ('jangling', 'NN'), ('discords', 'NNS'), ('nation', 'NN'), ('beautiful', 'JJ'), ('symphony', 'NN'), ('brotherhood', 'NN'), ('.', '.')]
